# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelhenrick1/GoogleCollab/blob/main/Teste2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
plot(mtcars)
# Out:
# plot without title

# %%
dados <- mtcars

# %%
plot(dados$mpg, dados$wt, pch=19, col="blue")
# Out:
# plot without title
