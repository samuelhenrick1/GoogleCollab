# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelhenrick1/GoogleCollab/blob/main/Trilha3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(-10,10,0.01)

plt.plot(x,np.sin(x))
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(-10,10,0.01)

plt.plot(x,np.sin(x), label='sin(x')
plt.plot(x,np.cos(4*x),label='cos(4x)')

plt.title('Exemplo Sin(x) & Cos (4x)')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.legend()

plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,4))
plt.suptitle('Script Layer', fontsize=14, weight='bold',y=1.05)

plt.subplot(1,2,1)
plt.plot(x,np.sin(x))
plt.title('Primeiro Plot')

plt.subplot(1,2,2)
plt.plot(x,np.cos(4*x))
plt.title('Segundo Plot')

plt.tight_layout()
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(1,2,figsize=(12,4))

plt.suptitle('Artist Layer', fontsize=14,weight='bold',y=1.05)

ax[0].plot(x,np.sin(x))
ax[0].set_title('Primeiro Plot')

ax[1].plot(x,np.cos(4*x))
ax[1].set_title('Segundo Plot')

plt.tight_layout()
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(0,6,0.3)

fig = plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.title('Explicit and Short Parameters',fontsize=14,weight='bold')

plt.plot(x,np.sin(x), color='springgreen', marker='o', linestyle='dashed', linewidth=2, markersize=6)
plt.plot(x,np.cos(x), color='slateblue', linestyle='dashdot', linewidth=2)

plt.plot(x,np.tanh(x), '--r',linewidth=2,markersize=6)
plt.plot(x,1/np.exp(x)*np.cos(x),'-.sb', linewidth=1,markersize=4)

plt.subplot(1,2,2)
plt.title('Enfatizando uma linha', fontsize=14,weight='bold')
plt.plot(x,np.sin(x),linewidth=1,alpha=0.7)
plt.plot(x,np.cos(x),linewidth=1,alpha=0.7)
plt.plot(x,1/np.exp(x)*np.cos(x),'--ok')

plt.tight_layout()
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

x = np.arange(0.0,1.1,0.1)

fig = plt.figure(figsize=(12,12))

plt.subplot(3,2,1)
plt.title('Lines Styles',fontsize=14,weight='bold')

plt.plot(x,x**1,linestyle='solid',label='solid')
plt.plot(x,x**2,linestyle='dashed',label='dashed')
plt.plot(x,x**3,linestyle='dashdot',label='dashdot')
plt.plot(x,x**4,linestyle='dotted',label='dotted')
plt.legend(title='Lines Styles')

plt.subplot(3,2,2)
plt.title('Basic Colors',fontsize=14,weight='bold')
plt.plot(x,x**1,color='r',label='r')
plt.plot(x,x**2,color='g',label='g')
plt.plot(x,x**3,color='b',label='b')
plt.plot(x,x**4,color='c',label='c')
plt.plot(x,x**5,color='m',label='m')
plt.plot(x,x**6,color='y',label='y')
plt.plot(x,x**7,color='k',label='k')
plt.legend(title='Colors')

plt.subplot(3,2,3)
plt.title('Gray Colors', fontsize=14, weight='bold')
plt.plot(x,x**1,  color='1',    label='1')
plt.plot(x,x**2,  color='0.75', label='0.75')
plt.plot(x,x**3,  color='0.5',  label='0.5')
plt.plot(x,x**4,  color='0.25', label='0.25')
plt.plot(x,x**5,  color='0.1',  label='0.1')
plt.legend(title='Gray level')

x = np.arange(0.0,1.1,0.1)

plt.subplot(3,2,4)
plt.title('Markers',fontsize=14,weight='bold')
plt.plot(x,x**1,marker='o',label='o')
plt.plot(x,x**2,marker='x',label='x')
plt.plot(x,x**3,marker='v',label='v')
plt.plot(x,x**4,marker='>',label='>')
plt.plot(x,x**5,marker='s',label='s')
plt.plot(x,x**6,marker='D',label='D')
plt.legend(title='Markers')

plt.subplot(3,2,5)
plt.title('Alpha',fontsize=14,weight='bold')
plt.plot(x,x**1,alpha=0.8,label='0.8')
plt.plot(x,x**2,alpha=0.7,label='0.7')
plt.plot(x,x**3,alpha=0.6,label='0.6')
plt.plot(x,x**4,alpha=0.5,label='0.5')
plt.plot(x,x**5,alpha=0.4,label='0.4')
plt.plot(x,x**6,alpha=0.3,label='0.3')
plt.legend(title='Transparency')

plt.subplot(3,2,6)
plt.title('Linewidht', fontsize=14, weight='bold')
plt.plot(x,x**1,color='0.5',linewidth=1.5,label='1.5')
plt.plot(x,x**2,color='0.5',linewidth=2,label='2')
plt.plot(x,x**3,color='0.5',linewidth=3.5,label='3.5')
plt.plot(x,x**4,color='0.5',linewidth=4,label='4')
plt.plot(x,x**5,color='0.5',linewidth=5,label='5')
plt.legend(title='Line width')



plt.tight_layout()
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

x = np.linspace=(-3,3,20)

plt.figure()

plt.plot(x,np.cos(x),label='cos(x)')
plt.plot(x,np.tanh(x),label='tanh(x)')

plt.title('Meu Titulo',color='green',fontsize=18,weight='bold',ha='center')

plt.xlabel('x value',color='red',fontsize=14)
plt.ylabel('f(x) value',color='blue',fontsize=14)

plt.legend(title='Minha Legenda',loc='best',fontsize='x-large')

plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

x = np.linspace=(-3,3,20) #FALTA UM SINAL DE IGUAL NA APOSTILA

fig = plt.figure(figsize=(12,4))
plt.suptitle('Adicionando Textos e Anotações no Gráfico',fontsize=14,weight='bold',y=1.05)

plt.subplot(1,2,1)
plt.title('Text, plot marker e h-vlines', fontsize=14, weight='bold')
plt.plot(x,np.tanh(x),'r--',alpha=0.5)
plt.plot(x,np.cos(x),'r--',alpha=0.5)
plt.ylim([-1.2,1.2])

plt.plot(0,1,marker = 'o', color = 'darkblue', markersize = 10)
plt.plot(0,0,marker = 'o', color = 'darkblue', markersize = 10)

plt.text(0+0.2,0-0.2,'Ponto Médio',style='italic',color='grey')
plt.text(0+0.2,1+0.05,'Ponto Máximo',style='italic',color='grey')
plt.text(-2.0,0.2,'Ascendente',style='italic',color='grey')
plt.text(1,0.2,'Descendente',style='italic',color='grey')

plt.vlines(0,-1,1.1,linestyle='dashed',color='b',linewidth=1)
plt.hlines(0,-3,3,linestyle='dashed',color='b',linewidth=1)

plt.subplot(1,2,2)
plt.title('Text e Annotations',fontsize=14,weight='bold')
plt.plot(x,(x+2)*(x-1)*(x-2),'r--',alpha=0.5)


plt.plot([-2,1,2],[0,0,0],'o',color='darkblue',markersize=1)

plt.text(-2+0.2,0-2.4,'(-2,0)',style='italic',color='dimgray')
plt.text(1+0.2,0-2.4,'(1,0)',style='italic',color='dimgray')
plt.text(2+0.2,0-2.4,'(2,0)',style='italic',color='dimgray')

plt.annotate('Ponto de Máximo Local',
             xy=(-1,6),
             xytext=(0,-15),
             arrowprops=dict(arrowstyle="->"))

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-e7c4f03725f6> in <module>()
#      28 plt.subplot(1,2,2)
#      29 plt.title('Text e Annotations',fontsize=14,weight='bold')
# ---> 30 plt.plot(x,(x+2)*(x-1)*(x-2),'r--',alpha=0.5)
#      31
#      32
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

x = np.linspace=(-3,3,200)

fig=plt.figure(figsize=(12,4))
plt.suptitle('Configurando XLIM e YLIM',fontsize=14,weight='bold',y=1.05)

plt.subplot(1,2,1)
plt.plot(x,np.cos(x))

plt.plot(x,np.tanh(x))

plt.subplot(1,2,2)
plt.plot(x,np.cos(x))
plt.plot(x,np.tanh(x))
plt.xlim([0,2])
plt.ylim([-3,3])

plt.tight_layout()
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

fig,ax=plt.subplots(1,2,figsize=(12,4),sharey=True,sharex=True)
plt.suptitle('Compartilhando o Eixos y',fontsize=14,weight='bold',y=1.05)

x=np.linspace=(-2,2,10000)

ax[0].set_title('$tanh(x_i)$',fontsize=16)
ax[0].plot(x,np.tanh(x))
ax[0].grid()

ax[1].set_title('$\\frac{1}{e^{x_i} cos(x_i)}$',fontsize=18)
ax[1].plot(x,1/np.exp(x)*np.cos(x))
ax[1].grid()

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: overflow encountered in exp
#   app.launch_new_instance()

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

x=np.random.random_sample(100)

plt.figure(figsize=(12,8))
plt.suptitle('Diferentes Estilos',fontsize=14,weight='bold',y=1.05)

i=1
for style in ['classic','fivethirtyeight','seaborn-pastel','ggplot']:
  with plt.style.context(style):
    plt.subplot(2,2,i)
    plt.plot(x)
    plt.title(style,fontsize=14,weight='bold')
    i=i+1

plt.tight_layout()
plt.show()

plt.style.context('default')
plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['savefig.dpi']=300
plt.plot(x)

plt.savefig('my_plot.png')
plt.savefig('my_plot.pdf')

plt.show()

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

flights = sns.load_dataset("flights")
flights.head()

plt.figure(figsize=(12,4))
flights_may = flights [ flights.month == 'May']
flights_dec = flights [ flights.month == 'Dec']

plt.subplot(1,2,1)
plt.plot(flights_may.year,flights_may.passengers,label='May')
plt.plot(flights_dec.year,flights_dec.passengers,label='Dec')
plt.title('With Matplotlib',fontsize=14,weight='bold')
plt.legend()

plt.subplot(1,2,2)
sns.lineplot(x=flights_may.year,y=flights_may.passengers, label='May')
sns.lineplot(x=flights_dec.year,y=flights_dec.passengers, label='Dec')
plt.title('With Seanborn',fontsize=14,weight='bold')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
df=px.data.gapminder()

plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(df.year,df.lifeExp)
plt.title('With Matplotlib',fontsize=14,weight='bold')
plt.text(1958,55,'Evite esse gráfico',fontsize=24,c='red',weight='bold')

plt.subplot(1,2,2)
sns.lineplot(x=df.year,y=df.lifeExp)

plt.title('WithSeaborn',fontsize=14,weight='bold')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
df=px.data.gapminder()

tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
df=px.data.gapminder()

tips = sns.load_dataset("tips")
tips.head()

plt.figure(figsize=(12,4))
tips_weekend = tips [ tips.day.isin(['Sun','Sat'])]
tips_week = tips [~tips.day.isin(['Sun','Sat'])]

plt.subplot(1,2,1)
plt.hist(tips_weekend.total_bill,alpha=0.6,label='weekend')
plt.hist(tips_week.total_bill,alpha=0.5,label='week')
plt.title('With Matplotlib',fontsize=14,weight='bold')
plt.legend()

plt.subplot(1,2,2)
sns.histplot(tips_weekend.total_bill,alpha=0.6,label='weekend')
sns.histplot(tips_week.total_bill,alpha=0.6,label='week')
plt.title('With Seanborn',fontsize=14,weight='bold')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-b21daa70f85f> in <module>()
#       9
#      10 plt.subplot(1,2,1)
# ---> 11 plt.hist(tips_weekend.total_bill,alpha=0.6,label='weekend')
#      12 plt.hist(tips_week.total_bill,alpha=0.5,label='week')
#      13 plt.title('With Matplotlib',fontsize=14,weight='bold')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6658             # this will automatically overwrite bins,
#    6659             # so that each histogram uses the same bins
# -> 6660             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6661             tops.append(m)
#    6662         tops = np.array(tops, float)  # causes problems later if it's an int
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     790     a, weights = _ravel_and_check_weights(a, weights)
#     791
# --> 792     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     793
#     794     # Histogram is an integer or a float array depending on the weights.
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     446         bin_edges = np.linspace(
#     447             first_edge, last_edge, n_equal_bins + 1,
# --> 448             endpoint=True, dtype=bin_type)
#     449         return bin_edges, (first_edge, last_edge, n_equal_bins)
#     450     else:
#
# TypeError: 'tuple' object is not callable

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
df=px.data.gapminder()

plt.figure(figsize=(12,4))
tips_weekend = tips [tips.day.isin(['Sun','Sat'])]
tips_week = tips [~tips.day.isin(['Sun','Sat'])]

plt.subplot(1,2,1)
plt.hist(tips_weekend.total_bill, density=True,alpha=0.6,label='weekend')
plt.hist(tips_week.total_bill,density=True,alpha=0.6,label='week')
plt.title('With Matplotlib',fontsize=14,weight='bold')
plt.legend()

plt.subplot(1,2,2)
sns.kdeplot(tips_weekend.total_bill,alpha=0.6,label='weekend')
sns.kdeplot(tips_week.total_bill,alpha=0.6,label='week')
plt.title('With Seaborn',fontsize=14,weight='bold')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-03ce7f8d58a6> in <module>()
#      10
#      11 plt.subplot(1,2,1)
# ---> 12 plt.hist(tips_weekend.total_bill, density=True,alpha=0.6,label='weekend')
#      13 plt.hist(tips_week.total_bill,density=True,alpha=0.6,label='week')
#      14 plt.title('With Matplotlib',fontsize=14,weight='bold')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6658             # this will automatically overwrite bins,
#    6659             # so that each histogram uses the same bins
# -> 6660             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6661             tops.append(m)
#    6662         tops = np.array(tops, float)  # causes problems later if it's an int
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     790     a, weights = _ravel_and_check_weights(a, weights)
#     791
# --> 792     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     793
#     794     # Histogram is an integer or a float array depending on the weights.
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     446         bin_edges = np.linspace(
#     447             first_edge, last_edge, n_equal_bins + 1,
# --> 448             endpoint=True, dtype=bin_type)
#     449         return bin_edges, (first_edge, last_edge, n_equal_bins)
#     450     else:
#
# TypeError: 'tuple' object is not callable

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
df=px.data.gapminder()

plt.figure(figsize=(12,4))
tips_weekend=tips[tips.day.isin(['Sun','Sat'])]
tips_week=tips[~tips.day.isin(['Sun','Sat'])]

plt.subplot(1,2,1)
plt.boxplot(tips_weekend.total_bill,positions = [0])
plt.boxplot(tips_week.total_bill,positions=[1])
plt.title('With Matplotlib',fontsize=14,weight='bold')
plt.xticks(ticks=[0,1],labels=['weekend','week'])

plt.subplot(1,2,2)
sns.boxplot(x='day',y='total_bill',hue='sex',data=tips)
plt.title('With Seanborn',fontsize=14,weight='bold')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-ea094a1c4a15> in <module>()
#      16
#      17 plt.subplot(1,2,2)
# ---> 18 sns.boxplot(x='day',y='total_bill',hue='sex',data=tips)
#      19 plt.title('With Seanborn',fontsize=14,weight='bold')
#      20
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2246     kwargs.update(dict(whis=whis))
#    2247
# -> 2248     plotter.plot(ax, kwargs)
#    2249     return ax
#    2250
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in plot(self, ax, boxplot_kws)
#     507     def plot(self, ax, boxplot_kws):
#     508         """Make the plot."""
# --> 509         self.draw_boxplot(ax, boxplot_kws)
#     510         self.annotate_axes(ax)
#     511         if self.orient == "h":
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in draw_boxplot(self, ax, kws)
#     449             else:
#     450                 # Draw nested groups of boxes
# --> 451                 offsets = self.hue_offsets
#     452                 for j, hue_level in enumerate(self.hue_names):
#     453
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in hue_offsets(self)
#     330         if self.dodge:
#     331             each_width = self.width / n_levels
# --> 332             offsets = np.linspace(0, self.width - each_width, n_levels)
#     333             offsets -= offsets.mean()
#     334         else:
#
# TypeError: 'tuple' object is not callable

# %%
plt.figure(figsize=(12,4))
flights_by_month = pd.DataFrame(flights.groupby('month').passengers.mean()).reset_index()
flights_by_min = pd.DataFrame(flights.groupby('month').passengers.min()).reset_index()

plt.subplot(1,2,1)
plt.bar(flights_by_month.month, flights_by_month.passengers, color ='r',alpha=0.6,label='mean')
plt.bar(flights_by_min.month, flights_by_min.passengers,color='g',alpha=0.8,label='min')
plt.title('With Matplotlib',fontsize=14,weight='bold')
plt.legend()

plt.subplot(1,2,2)
sns.barplot(x=flights_by_month.month,y=flights_by_month.passengers,color='r',alpha=0.6,label='mean')
sns.barplot(x=flights_by_min.month, y=flights_by_min.passengers,color='g',alpha=0.8,label='min')
plt.title('With Seanborn',fontsize=14,weight='bold')
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.bar(flights.month,flights.passengers,color='r',alpha=0.3)
plt.title('Com Matplotlib',fontsize=14,weight='bold')
plt.text(1,250,'Evite Esse Gráfico',fontsize=24,c='grey',weight='bold')

plt.subplot(1,2,2)
sns.barplot(x=flights.month,y=flights.passengers,color='r',alpha=0.8)
plt.title('Com Seaborn',fontsize=14,weight='bold')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

tips_group = pd.DataFrame(tips.groupby('day').total_bill.mean()).reset_index()

labels = tips_group.day
sections = tips_group.total_bill
colors = ['c','g','y','b']

plt.pie(sections, labels=labels, colors = colors,startangle = 90,explode = (0,0,0,0.1),autopct = '%1.2f%%')

plt.axis('equal')
plt.title('Com Matplotlib', fontsize=14,weight='bold')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-e8b1715d8458> in <module>()
#       9 colors = ['c','g','y','b']
#      10
# ---> 11 plt.pie(sections, labels=labels, colors = colors,startangle = 90,explode = (0,0,0,0.1),autopct = '%1.2f%%')
#      12
#      13 plt.axis('equal')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, data)
#    2753         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2754         frame=frame, rotatelabels=rotatelabels, **({"data": data} if
# -> 2755         data is not None else {}))
#    2756
#    2757
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    2970                                360. * max(theta1, theta2),
#    2971                                facecolor=get_next_color(),
# -> 2972                                **wedgeprops)
#    2973             slices.append(w)
#    2974             self.add_patch(w)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/patches.py in __init__(self, center, r, theta1, theta2, width, **kwargs)
#    1109         self.theta1, self.theta2 = theta1, theta2
#    1110         self._patch_transform = transforms.IdentityTransform()
# -> 1111         self._recompute_path()
#    1112
#    1113     def _recompute_path(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/patches.py in _recompute_path(self)
#    1121
#    1122         # Form the outer ring
# -> 1123         arc = Path.arc(theta1, theta2)
#    1124
#    1125         if self.width is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/path.py in arc(cls, theta1, theta2, n, is_wedge)
#     871         alpha = np.sin(deta) * (np.sqrt(4.0 + 3.0 * t * t) - 1) / 3.0
#     872
# --> 873         steps = np.linspace(eta1, eta2, n + 1, True)
#     874         cos_eta = np.cos(steps)
#     875         sin_eta = np.sin(steps)
#
# TypeError: 'tuple' object is not callable

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

flights = flights.pivot("month","year","passagers")
sns.heatmap(flights)
plt.title('With Seaborn',fontsize=14,weight='bold')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'passagers'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-000fb107aa1a> in <module>()
#       5 import seaborn as sns
#       6
# ----> 7 flights = flights.pivot("month","year","passagers")
#       8 sns.heatmap(flights)
#       9 plt.title('With Seaborn',fontsize=14,weight='bold')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    6676         from pandas.core.reshape.pivot import pivot
#    6677
# -> 6678         return pivot(self, index=index, columns=columns, values=values)
#    6679
#    6680     _shared_docs[
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     474             )
#     475         else:
# --> 476             indexed = data._constructor_sliced(data[values]._values, index=index)
#     477     return indexed.unstack(columns)
#     478
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'passagers'

# %%
plt.figure(figsize=(12,4))
tips_weekend = tips[tips.day.isin(['Sun','Sat'])]
tips_week= tips[~tips.day.isin(['Sun','Sat'])]

plt.subplot(1,2,1)
plt.scatter(tips_weekend.total_bill,tips_weekend.tip,alpha=0.6,label='weekend')
plt.scatter(tips_week.total_bill,tips_week.tip,alpha=0.6,label='week')
plt.title('Com Matplotlib',fontsize=14,weight='bold')
plt.legend()

plt.subplot(1,2,2)
sns.scatterplot(x=tips_weekend.total_bill,y=tips_week.tip,alpha=0.6,label='weekend')
sns.scatterplot(x=tips_week.total_bill,y=tips_week.tip,alpha=0.6,label='week')
plt.title('Com Seaborn',fontsize=14,weight='bold')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

sns.regplot(x='total_bill',y='tip',data=tips)
plt.title('Com Seaborn',fontsize=14,weight='bold')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-69b5c912fc4d> in <module>()
#       5 import seaborn as sns
#       6
# ----> 7 sns.regplot(x='total_bill',y='tip',data=tips)
#       8 plt.title('Com Seaborn',fontsize=14,weight='bold')
#       9
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     836     scatter_kws["marker"] = marker
#     837     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 838     plotter.plot(ax, scatter_kws, line_kws)
#     839     return ax
#     840
#
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py in plot(self, ax, scatter_kws, line_kws)
#     368
#     369         if self.fit_reg:
# --> 370             self.lineplot(ax, line_kws)
#     371
#     372         # Label the axes
#
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py in lineplot(self, ax, kws)
#     411         """Draw the model."""
#     412         # Fit the regression model
# --> 413         grid, yhat, err_bands = self.fit_regression(ax)
#     414         edges = grid[0], grid[-1]
#     415
#
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py in fit_regression(self, ax, x_range, grid)
#     199                 else:
#     200                     x_min, x_max = ax.get_xlim()
# --> 201             grid = np.linspace(x_min, x_max, 100)
#     202         ci = self.ci
#     203
#
# TypeError: 'tuple' object is not callable

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

sns.pairplot(data=tips)
plt.title('Com Searborn',fontsize=14,weight='bold')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-72959db11dde> in <module>()
#       5 import seaborn as sns
#       6
# ----> 7 sns.pairplot(data=tips)
#       8 plt.title('Com Searborn',fontsize=14,weight='bold')
#       9
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2017     diag_kws.setdefault("legend", False)
#    2018     if diag_kind == "hist":
# -> 2019         grid.map_diag(histplot, **diag_kws)
#    2020     elif diag_kind == "kde":
#    2021         diag_kws.setdefault("fill", True)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in map_diag(self, func, **kwargs)
#    1400             plot_kwargs.setdefault("hue_order", self._hue_order)
#    1401             plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1402             func(x=vector, **plot_kwargs)
#    1403             self._clean_axis(ax)
#    1404
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1434             estimate_kws=estimate_kws,
#    1435             line_kws=line_kws,
# -> 1436             **kwargs,
#    1437         )
#    1438
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     435
#     436             # Do the histogram computation
# --> 437             heights, edges = estimator(observations, weights=weights)
#     438
#     439             # Rescale the smoothed curve to match the histogram
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_statistics.py in __call__(self, x1, x2, weights)
#     369         """Count the occurrances in each bin, maybe normalize."""
#     370         if x2 is None:
# --> 371             return self._eval_univariate(x1, weights)
#     372         else:
#     373             return self._eval_bivariate(x1, x2, weights)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_statistics.py in _eval_univariate(self, x, weights)
#     346         bin_edges = self.bin_edges
#     347         if bin_edges is None:
# --> 348             bin_edges = self.define_bin_edges(x, weights=weights, cache=False)
#     349
#     350         density = self.stat == "density"
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_statistics.py in define_bin_edges(self, x1, x2, weights, cache)
#     264
#     265             bin_edges = self._define_bin_edges(
# --> 266                 x1, weights, self.bins, self.binwidth, self.binrange, self.discrete,
#     267             )
#     268
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_statistics.py in _define_bin_edges(self, x, weights, bins, binwidth, binrange, discrete)
#     255         else:
#     256             bin_edges = np.histogram_bin_edges(
# --> 257                 x, bins, binrange, weights,
#     258             )
#     259         return bin_edges
#
# <__array_function__ internals> in histogram_bin_edges(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in histogram_bin_edges(a, bins, range, weights)
#     666     """
#     667     a, weights = _ravel_and_check_weights(a, weights)
# --> 668     bin_edges, _ = _get_bin_edges(a, bins, range, weights)
#     669     return bin_edges
#     670
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     446         bin_edges = np.linspace(
#     447             first_edge, last_edge, n_equal_bins + 1,
# --> 448             endpoint=True, dtype=bin_type)
#     449         return bin_edges, (first_edge, last_edge, n_equal_bins)
#     450     else:
#
# TypeError: 'tuple' object is not callable

# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

sns.heatmap(tips[['total_bill','tip','size']].corr())
plt.title('With Seaborn',fontsize=14,weight='bold')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-3ec5f30e6056> in <module>()
#       8 import seaborn as sns
#       9
# ---> 10 sns.heatmap(tips[['total_bill','tip','size']].corr())
#      11 plt.title('With Seaborn',fontsize=14,weight='bold')
#      12
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     546     if square:
#     547         ax.set_aspect("equal")
# --> 548     plotter.plot(ax, cbar_ax, kwargs)
#     549     return ax
#     550
#
# /usr/local/lib/python3.7/dist-packages/seaborn/matrix.py in plot(self, ax, cax, kws)
#     306         # Possibly add a colorbar
#     307         if self.cbar:
# --> 308             cb = ax.figure.colorbar(mesh, cax, ax, **self.cbar_kws)
#     309             cb.outline.set_linewidth(0)
#     310             # If rasterized is passed to pcolormesh, also rasterize the
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    2236                              'panchor']
#    2237         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
# -> 2238         cb = cbar.colorbar_factory(cax, mappable, **cb_kw)
#    2239
#    2240         self.sca(current_ax)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/colorbar.py in colorbar_factory(cax, mappable, **kwargs)
#    1683         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1684     else:
# -> 1685         cb = Colorbar(cax, mappable, **kwargs)
#    1686
#    1687     cid = mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, **kw)
#    1228                 kw['alpha'] = mappable.get_alpha()
#    1229
# -> 1230             ColorbarBase.__init__(self, ax, **kw)
#    1231
#    1232     def on_mappable_changed(self, mappable):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/colorbar.py in __init__(self, ax, cmap, norm, alpha, values, boundaries, orientation, ticklocation, extend, spacing, ticks, format, drawedges, filled, extendfrac, extendrect, label)
#     504         else:
#     505             self.formatter = format  # Assume it is a Formatter or None
# --> 506         self.draw_all()
#     507
#     508     def _extend_lower(self):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/colorbar.py in draw_all(self)
#     527         # sets self._boundaries and self._values in real data units.
#     528         # takes into account extend values:
# --> 529         self._process_values()
#     530         # sets self.vmin and vmax in data units, but just for
#     531         # the part of the colorbar that is not part of the extend
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/colorbar.py in _process_values(self, b)
#     972                 expander=0.1)
#     973
# --> 974             b = self.norm.inverse(self._uniform_y(self.cmap.N + 1))
#     975
#     976             if isinstance(self.norm, (colors.PowerNorm, colors.LogNorm)):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/colorbar.py in _uniform_y(self, N)
#    1049         '''
#    1050         if self.extend == 'neither':
# -> 1051             y = np.linspace(0, 1, N)
#    1052         else:
#    1053             automin = automax = 1. / (N - 1.)
#
# TypeError: 'tuple' object is not callable

# %%
import plotly.express as px
df = px.data.gapminder()
df = df [df.country.isin(['Brazil','France','United States','Angola','Japan','China','Somalia','India'])]
fig = px.line(df, x="year",y="lifeExp",color="country",title='Expectativas de Vida dos Países')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f09ec55a-dc97-477a-9d2a-19cf4603fa55" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f09ec55a-dc97-477a-9d2a-19cf4603fa55")) {
#                     Plotly.newPlot(
#                         'f09ec55a-dc97-477a-9d2a-19cf4603fa55',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Angola<br>year=%{x}<br>lifeExp=%{y}", "legendgroup": "country=Angola", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "country=Angola", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [30.015, 31.999000000000002, 34.0, 35.985, 37.928000000000004, 39.483000000000004, 39.942, 39.906, 40.647, 40.963, 41.003, 42.731], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Brazil<br>year=%{x}<br>lifeExp=%{y}", "legendgroup": "country=Brazil", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "country=Brazil", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [50.917, 53.285, 55.665, 57.632, 59.504, 61.489, 63.336000000000006, 65.205, 67.057, 69.388, 71.006, 72.39], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=China<br>year=%{x}<br>lifeExp=%{y}", "legendgroup": "country=China", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "country=China", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [44.0, 50.54896, 44.50136, 58.381119999999996, 63.118880000000004, 63.96736, 65.525, 67.274, 68.69, 70.426, 72.028, 72.961], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=France<br>year=%{x}<br>lifeExp=%{y}", "legendgroup": "country=France", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "country=France", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [67.41, 68.93, 70.51, 71.55, 72.38, 73.83, 74.89, 76.34, 77.46, 78.64, 79.59, 80.657], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=India<br>year=%{x}<br>lifeExp=%{y}", "legendgroup": "country=India", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "country=India", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [37.373000000000005, 40.249, 43.605, 47.193000000000005, 50.651, 54.208, 56.596000000000004, 58.553000000000004, 60.223, 61.765, 62.879, 64.69800000000001], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Japan<br>year=%{x}<br>lifeExp=%{y}", "legendgroup": "country=Japan", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "country=Japan", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [63.03, 65.5, 68.73, 71.43, 73.42, 75.38, 77.11, 78.67, 79.36, 80.69, 82.0, 82.603], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=Somalia<br>year=%{x}<br>lifeExp=%{y}", "legendgroup": "country=Somalia", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "lines", "name": "country=Somalia", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [32.978, 34.977, 36.981, 38.977, 40.973, 41.974, 42.955, 44.501000000000005, 39.658, 43.795, 45.93600000000001, 48.159], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "country=United States<br>year=%{x}<br>lifeExp=%{y}", "legendgroup": "country=United States", "line": {"color": "#B6E880", "dash": "solid"}, "mode": "lines", "name": "country=United States", "showlegend": true, "type": "scatter", "x": [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007], "xaxis": "x", "y": [68.44, 69.49, 70.21, 70.76, 71.34, 73.38, 74.65, 75.02, 76.09, 76.81, 77.31, 78.242], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter":

# %%
import seaborn as sns
import pandas as pd


x = np.random.random_sample(100)
np.random.seed(1234)

x = np.arange(0,100,1)
y = np.random.rand(100)*10
z = np.random.rand(100)*3
t = np.random.rand(100)*5

from matplotlib import cm

plt.figure(figsize=(12,12))
plt.suptitle('outros Gráficos',fontsize=14,weight='bold',y=1.05)

plt.subplot(3,2,1)
plt.plot(x,y)
plt.title('Plot,',fontsize=14,weight='bold')

plt.subplot(3,2,2)
plt.hist(y,bins=30,color='g',alpha=0.5)
plt.title('Histograma',fontsize=14,weight='bold')

plt.subplot(3,2,3)
plt.scatter(x,y,c=x,cmap=cm.viridis)
plt.title('Scatter plot',fontsize=14,weight='bold')

plt.subplot(3,2,4)
plt.boxplot([y,z,t],labels=['Cyan','Green','Yellow'])

plt.title('Box plot', fontsize=14, weight='bold')

plt.subplot(3,2,5)
plt.bar(['Cyan','Green','Yellow'],[y.mean(),z.mean(),t.mean()],color=['c','g','y'],alpha=0.5)
plt.title('Bar plot',fontsize=14,weight='bold')

plt.subplot(3,2,6)
plt.pie([y.mean(),z.mean(),t.mean()],
        colors=['c','g','y'],
        explode=[0,0.1,0],
        label=['Cyan','Green','Yellow'],
        autpct='%1.2f%%')

plt.title('Pie Plot',fontsize=14,weight='bold')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-b709893446db> in <module>()
#      21
#      22 plt.subplot(3,2,2)
# ---> 23 plt.hist(y,bins=30,color='g',alpha=0.5)
#      24 plt.title('Histograma',fontsize=14,weight='bold')
#      25
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2608         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2609         color=color, label=label, stacked=stacked, **({"data": data}
# -> 2610         if data is not None else {}), **kwargs)
#    2611
#    2612
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6658             # this will automatically overwrite bins,
#    6659             # so that each histogram uses the same bins
# -> 6660             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6661             tops.append(m)
#    6662         tops = np.array(tops, float)  # causes problems later if it's an int
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     790     a, weights = _ravel_and_check_weights(a, weights)
#     791
# --> 792     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     793
#     794     # Histogram is an integer or a float array depending on the weights.
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     446         bin_edges = np.linspace(
#     447             first_edge, last_edge, n_equal_bins + 1,
# --> 448             endpoint=True, dtype=bin_type)
#     449         return bin_edges, (first_edge, last_edge, n_equal_bins)
#     450     else:
#
# TypeError: 'tuple' object is not callable

# %%
import seaborn as sns
import pandas as pd


x = np.random.random_sample(100)
np.random.seed(1234)

x = np.arange(0,100,1)
y = np.random.rand(100)*10
z = np.random.rand(100)*3
t = np.random.rand(100)*5

from matplotlib import cm


fig, ax = plt.subplots(3,2,figsize=(12,12))

plt.suptitle('Outros graficos',fontsize=14,weight='bold',y=1.05)

sns.lineplot(x=x,y=y,ax=ax[0,0])
ax[0,0].set_title('Plot',fontsize=14,weight='bold')

sns.histplot(y,bins=30,color='g',alpha=0.5,ax=ax[0,1])
ax[0,1].set_title('Histograma',fontsize=14,weight='bold')

sns.scatterplot(x=x,y=y,c=x,cmap=cm.viridis,ax=ax[1,0])
ax[1,0].set_title('Scatter Plot',fontsize=14,weight='bold')

box=pd.DataFrame({'Cyan':y,'Green':z,'Yellow':t})
sns.boxplot(data=box,ax=ax[1,1])
ax[1,1].set_title('Box Plot', fontsize=14,weight='bold')

sns.barplot(x=['Cyan','Green','Yellow'],y=[y.mean(),z.mean(),t.mean()],aplha=0.5,ax=ax[2,0])
ax[2,0].set_title('Bar Plot',fontsize=14,weight='bold')

plt.tight_layout
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-45cf068da427> in <module>()
#      21 ax[0,0].set_title('Plot',fontsize=14,weight='bold')
#      22
# ---> 23 sns.histplot(y,bins=30,color='g',alpha=0.5,ax=ax[0,1])
#      24 ax[0,1].set_title('Histograma',fontsize=14,weight='bold')
#      25
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1434             estimate_kws=estimate_kws,
#    1435             line_kws=line_kws,
# -> 1436             **kwargs,
#    1437         )
#    1438
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     435
#     436             # Do the histogram computation
# --> 437             heights, edges = estimator(observations, weights=weights)
#     438
#     439             # Rescale the smoothed curve to match the histogram
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_statistics.py in __call__(self, x1, x2, weights)
#     369         """Count the occurrances in each bin, maybe normalize."""
#     370         if x2 is None:
# --> 371             return self._eval_univariate(x1, weights)
#     372         else:
#     373             return self._eval_bivariate(x1, x2, weights)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_statistics.py in _eval_univariate(self, x, weights)
#     346         bin_edges = self.bin_edges
#     347         if bin_edges is None:
# --> 348             bin_edges = self.define_bin_edges(x, weights=weights, cache=False)
#     349
#     350         density = self.stat == "density"
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_statistics.py in define_bin_edges(self, x1, x2, weights, cache)
#     264
#     265             bin_edges = self._define_bin_edges(
# --> 266                 x1, weights, self.bins, self.binwidth, self.binrange, self.discrete,
#     267             )
#     268
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_statistics.py in _define_bin_edges(self, x, weights, bins, binwidth, binrange, discrete)
#     255         else:
#     256             bin_edges = np.histogram_bin_edges(
# --> 257                 x, bins, binrange, weights,
#     258             )
#     259         return bin_edges
#
# <__array_function__ internals> in histogram_bin_edges(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in histogram_bin_edges(a, bins, range, weights)
#     666     """
#     667     a, weights = _ravel_and_check_weights(a, weights)
# --> 668     bin_edges, _ = _get_bin_edges(a, bins, range, weights)
#     669     return bin_edges
#     670
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     446         bin_edges = np.linspace(
#     447             first_edge, last_edge, n_equal_bins + 1,
# --> 448             endpoint=True, dtype=bin_type)
#     449         return bin_edges, (first_edge, last_edge, n_equal_bins)
#     450     else:
#
# TypeError: 'tuple' object is not callable
