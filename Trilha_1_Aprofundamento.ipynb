# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelhenrick1/GoogleCollab/blob/main/Trilha_1_Aprofundamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#AQUISIÇÃO DE DADOS
import urllib.request  

texto = []

for line in urllib.request.urlopen('https://raw.githubusercontent.com/samuelhenrick1/GoogleCollab/main/Trilha1.txt'): 
    texto.append(line.decode('utf-8'))

for i in range(len(texto)):
    texto[i] = texto[i].lower()
    texto[i] = texto[i].replace('\n','')
    texto[i] = texto[i].replace('.','')
    texto[i] = texto[i].replace(',','')
    texto[i] = texto[i].replace('(','')
    texto[i] = texto[i].replace(')','')
    texto[i] = texto[i].replace('?','')
    texto[i] = texto[i].replace('\'','')

# %%
#Construção do Dicionário

mydict = {}                             # crie um dicionário vazio

for line in texto:

  line = line.lower()                   # converte para lower
  words = line.split()                  # separa cada palavra
#  print(words)

  for word in words:                      # para cada palavra em words
    if word not in mydict.keys():         # se palavra não está no dicionário 
      mydict[word] = 1                    # acrescenta a word com o valor 1
    else:                                 # se a entrada já existe 
      mydict[word] =  mydict[word] + 1    # apenas soma 1 ao valor já existente

print(mydict)
# Out:
# {'2': 6, 'capítulo': 4, 'i': 2, '–': 3, 'referêncial': 1, 'teórico': 2, 'nesse': 3, 'veremos': 1, 'o': 128, 'tema': 1, 'e': 91, 'abordaremos': 1, 'a': 128, 'atual': 4, 'realidade': 3, 'dele': 3, 'com': 39, 'base': 7, 'em': 48, 'observações': 1, 'informações': 14, 'que': 128, 'vemos': 3, 'jornais': 1, 'revistas': 1, 'das': 11, 'são': 12, 'veiculadas': 1, 'pelo': 9, 'rádio': 1, 'tv': 1, 'por': 26, 'nossa': 2, 'experiência': 1, 'de': 287, 'vida': 1, 'também': 15, 'será': 3, 'desenvolvido': 7, 'referencial': 1, 'conceitos': 1, 'técnicas': 4, 'necessárias': 1, 'teses': 1, 'livros': 1, 'filmes': 1, 'arquivos': 3, 'digitais': 1, 'trabalhos': 1, 'científicos': 1, 'entre': 8, 'outros': 3, 'muitos': 3, 'dos': 14, 'assuntos': 1, 'aqui': 1, 'serão': 2, 'abordados': 1, 'foram': 5, 'recomendados': 1, 'pelos': 1, 'entrevistados': 1, 'para': 54, 'realização': 2, 'do': 43, 'projeto': 1, 'final': 1, 'neste': 2, 'caso': 4, 'tratando-se': 1, 'uma': 52, 'aprimoração': 1, 'um': 55, 'sistema': 14, 'tunelamento': 13, 'estável': 1, 'os': 27, 'noticiários': 1, 'as': 9, 'principais': 2, 'fontes': 1, 'democrática': 1, 'serviço': 13, 'da': 41, 'população': 2, 'sendo': 3, 'principal': 1, 'meio': 2, 'comunicação': 3, 'todos': 8, 'tempos': 1, 'indo': 1, 'lugares': 1, 'onde': 10, 'nem': 1, 'conseguem': 1, 'chegar': 1, 'trazendo': 1, 'à': 7, 'tona': 2, 'ficariam': 1, 'obstantes': 1, 'sem': 5, 'excelência': 1, 'deste': 7, 'trabalho': 9, 'comunicativo': 1, 'desde': 2, 'dezembro': 1, '2019': 4, 'na': 23, 'china': 1, 'ocorreu': 1, 'primeira': 2, 'contaminação': 2, 'novo': 3, 'coronavírus': 1, 'imprensa': 1, 'tem': 6, 'redobrados': 1, 'esforços': 1, 'seu': 8, 'respeitável': 2, 'papel': 1, 'perante': 1, 'sociedade': 1, 'informar': 1, 'índices': 1, 'contágios': 1, 'vírus': 3, 'vem': 1, 'crescendo': 1, 'cada': 5, 'dia': 1, 'determinadamente': 1, 'março': 1, '2021': 7, 'isto': 2, 'é': 80, 'quase': 1, 'três': 2, 'meses': 1, 'após': 1, 'primeiro': 2, 'confirmado': 1, 'organização': 2, 'mundial': 2, 'saúde': 3, 'oms': 1, 'trata': 4, 'disseminação': 2, 'como': 27, 'pandemia': 3, 'deixando': 2, 'ser': 16, 'epidemia': 1, 'necessidade': 3, 'conter': 2, 'essa': 5, 'órgão': 1, 'ressaltou': 1, 'importância': 3, 'distanciamento': 3, 'social': 4, 'não': 20, 'aglomerações': 1, 'pessoas': 6, 'qual': 8, 'países': 1, 'governos': 1, 'adotaram': 1, 'medidas': 1, 'importantes': 3, 'número': 6, 'mortes': 2, 'contaminações': 1, 'fim': 10, 'colapsar': 1, 'atuais': 2, 'sistemas': 4, 'província': 1, 'produção': 1, 'desta': 5, 'pesquisa': 6, 'mundo': 4, 'inteiro': 2, 'padece': 1, 'ainda': 7, 'pela': 8, 'covid-19': 1, 'cenário': 2, 'muito': 1, 'delicado': 1, 'requer': 1, 'todas': 2, 'independentemente': 1, 'qualquer': 7, 'espécie': 2, 'sejam': 3, 'raça': 1, 'cor': 1, 'sexo': 1, 'língua': 2, 'religião': 1, 'opinião': 1, 'política': 2, 'ou': 22, 'outra': 5, 'natureza': 1, 'origem': 1, 'nacional': 1, 'riqueza': 1, 'nascimento': 3, 'condição': 1, 'nobre': 1, 'atitude:': 1, 'solidariedade': 1, 'empatia': 1, 'próximo': 1, 'continentes': 1, 'encontramos': 1, 'cenas': 1, 'idênticas': 1, 'hospitais': 1, 'lotados': 1, 'médicos': 1, 'enfermeiros': 1, 'linha': 1, 'frente': 1, 'salvar': 1, 'pouco': 1, 'conhecido': 3, 'devastador': 1, 'cidades': 1, 'desertas': 1, 'crises': 1, 'econômicas': 1, 'tudo': 1, 'isso': 2, 'ao': 11, 'mesmo': 2, 'tempo': 1, 'fazendo': 1, 'se': 18, 'prepare': 1, 'enfrentar': 1, 'vencer': 1, 'esse': 9, 'momento': 2, 'catastrófico': 1, 'busca': 1, 'sobrevivência': 1, 'tanto': 1, 'físicas': 1, 'jurídicas': 1, 'precisaram': 1, 'readequar': 1, 'suas': 6, 'atividades': 1, 'modelo': 1, 'seguro': 5, 'evitar': 1, 'mais': 16, 'garantir': 2, 'econômico': 1, 'colapsei': 1, 'segundo': 3, 'dados': 18, 'companhia': 2, 'metropolitano': 1, 'paulo': 1, 'cmsp': 1, 'paulista': 1, 'trens': 1, 'metropolitanos': 1, 'cptm': 1, 'através': 13, 'consultas': 1, 'públicas': 1, 'divulgadas': 1, 'seguintes': 2, 'estatísticas': 1, 'transporte': 6, 'passageiros': 3, 'linhas': 2, 'espelha': 1, 'blog': 3, 'metrô-cptm:': ...

# %%
#EXIBIÇÃO DOS RESULTADOS

import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 4] # somente termos com mais de 4 ocorrências
# df = df.iloc[ np.int(len(df)/2) - 10 : np.int(len(df)/2) + 10 ] # para livros ou textos com muitos termos limita a um número mínimo de termos

plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()

# %%
#EXIBIÇÃO DOS RESULTADOS LIMITADOS A NÚMERO MINIMO DE TERMOS

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

df = pd.DataFrame(mydict.items(),  columns=['word', 'count']).sort_values('count',ascending=False)
df = df[df['count'] > 4] # somente termos com mais de 4 ocorrências
df = df.iloc[ np.int(len(df)/2) - 10 : np.int(len(df)/2) + 10 ] # para livros ou textos com muitos termos limita a um número mínimo de termos

plt.figure(figsize=(24,10))
mpl.style.use(['seaborn'])
sns.barplot(x=df.word,y=df['count'])
plt.xticks(rotation=90) 

plt.show()
